# %%
# testing yahoo_fin API. Look here for documentation: https://theautomatic.net/yahoo_fin-documentation/
# Can we get historical data for price, earnings, dividends for individual companies and for S&P500 index?
# Can we get other useful historical data from this API?

from yahoo_fin import stock_info as si

# %%
# get all historical dividend data
msft_dividends = si.get_dividends("msft")
 
# dividends from 2010 onward
msft_div_2010_plus = si.get_dividends("msft", "01-01-2010")

print(type(msft_dividends)) # Is it a dataframe?
print(msft_dividends.shape) # what is the shape?
display(msft_dividends.head(20)) # How often are dividends reported?

# looks like dividends are reported quarterly after 2004.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (79, 2)
#             dividend ticker
# 2003-02-19      0.08   MSFT
# 2003-10-15      0.16   MSFT
# 2004-08-23      0.08   MSFT
# 2004-11-15      3.08   MSFT
# 2005-02-15      0.08   MSFT
# 2005-05-16      0.08   MSFT
# 2005-08-15      0.08   MSFT
# 2005-11-15      0.08   MSFT
# 2006-02-15      0.09   MSFT
# 2006-05-15      0.09   MSFT
# 2006-08-15      0.09   MSFT
# 2006-11-14      0.10   MSFT
# 2007-02-13      0.10   MSFT
# 2007-05-15      0.10   MSFT
# 2007-08-14      0.10   MSFT
# 2007-11-13      0.11   MSFT
# 2008-02-19      0.11   MSFT
# 2008-05-13      0.11   MSFT
# 2008-08-19      0.11   MSFT
# 2008-11-18      0.13   MSFT
