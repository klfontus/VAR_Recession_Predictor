# %%
"""
#Wharton Research Data Services
#import module, created automated login
pip install wrds
import wrds 
db = wrds.Connection(wrds_username='kfontus3')
db.create_pgpass_file()
#just testing closing connection and reopening it. Don't have to reinput password!
#db.close()
db = wrds.Connection(wrds_username='kfontus3')

##snapshot = db.get_table(library='compsamp_snapshot', table='wrds_csq_unrestated')
var_names = ["gvkey", "rectq", "actq", "lctq", "atq", "ppentq", "dlttq", "dpq", "cogsq", "xsgaq", "oancfy", "ibq", "cisecglq"]
db.describe_table(library="compsamp_snapshot", table='wrds_csq_unrestated') #this takes forever to run bc it has 104k rows, so I downloaded it manually from the website

snapshot.shape
snapshot2 = snapshot[["gvkey", "rectq", "actq", "lctq", "atq", "ppentq", "dlttq", "dpq", "cogsq", "xsgaq", "oancfy", "ibq", "cisecglq"]]
snapshot2
"""

# %%
#!pip install pandas
import pandas as pd

m_data = pd.read_csv("M data 3.csv")
m_data.shape
# Out:
# (78625, 19)

# %%
m_data.head()
# Out:
#    gvkey  fyearq    datadate   ACTQ    ATQ  CISECGLQ  COGSQ  DLTTQ    DPQ  \
# 0   1018    1982   9/30/1981    NaN    NaN       NaN  0.724    NaN  0.052
# 1   1018    1982  12/31/1981    NaN    NaN       NaN  0.772    NaN  0.054
# 2   1018    1982   3/31/1982    NaN    NaN       NaN  0.740    NaN  0.057
# 3   1018    1982   6/30/1982  1.230  3.747       NaN  0.686  6.572  0.064
# 4   1018    1983   9/30/1982  1.445  3.913       NaN  0.688  6.570  0.051
#
#      IBQ   LCTQ  OANCFY  PPENTQ  RECTQ  SALEQ  XSGAQ conm  sic  tic
# 0  0.027    NaN     NaN     NaN    NaN  1.456  0.480  NaN  NaN  NaN
# 1  0.097    NaN     NaN     NaN    NaN  1.574  0.488  NaN  NaN  NaN
# 2 -0.398    NaN     NaN     NaN    NaN  1.130  0.570  NaN  NaN  NaN
# 3  0.296  0.484     NaN   2.362  0.712  1.662  0.427  NaN  NaN  NaN
# 4  0.010  0.643     NaN   2.313  0.691  1.299  0.391  NaN  NaN  NaN

# %%
m_data.describe()
# Out:
#                gvkey        fyearq           ACTQ            ATQ  \
# count   78625.000000  78625.000000   63596.000000   67186.000000
# mean    45225.223033   1995.698862     653.325254    1983.959785
# std     58690.246369     10.113799    3863.875625   12548.330512
# min      1018.000000   1973.000000      -0.168000      -0.250000
# 25%      7692.000000   1988.000000       6.314000      14.667000
# 50%     14282.000000   1996.000000      34.924000      83.839000
# 75%     63726.000000   2004.000000     173.045500     504.212500
# max    311524.000000   2013.000000  101466.000000  721739.000000
#
#            CISECGLQ         COGSQ          DLTTQ           DPQ           IBQ  \
# count  14664.000000  70993.000000   67391.000000  63529.000000  72775.000000
# mean       0.085395    284.540474     422.084094     24.169664     25.507324
# std       34.439396   1613.130672    4415.235776    130.734060    313.461168
# min    -2587.000000    -21.282000       0.000000    -71.173000 -18758.725000
# 25%        0.000000      1.521000       0.030000      0.104000     -0.507000
# 50%        0.000000     11.066000       4.725000      0.800000      0.242000
# 75%        0.000000     71.852000      92.478000      5.430000      3.947000
# max      980.705000  56094.336000  422859.000000   5699.613000  22628.000000
#
#                LCTQ        OANCFY        PPENTQ          RECTQ         SALEQ  \
# count  63818.000000  47994.000000  66787.000000   64578.000000  72766.000000
# mean     449.056330    139.252610    646.855061     359.472913    408.186195
# std     2735.197931   1040.359427   3050.399550    6431.264037   2146.022955
# min       -0.007000 -44236.938000      0.000000      -0.034000   -196.736000
# 25%        3.124250     -1.168000      2.194500       1.220000      2.328000
# 50%       16.901000      0.595000     16.899000      10.409000     17.726000
# 75%       92.363750     17.905000    134.164500      60.547000    107.918000
# max    69209.357000  31626.000000  92887.497000  573439.000000  69878.625000
#
#               XSGAQ           sic
# count  58783.000000  48210.000000
# mean      78.536667   4160.270794
# std      480.867336   2135.356370
# min      -49.436000    100.000000
# 25%        1.007000   2834.000000
# 50%        4.242000   3672.000000
# 75%       18.905000   5411.000000
# max    22654.688000   9997.000000

# %%
#the paper made its calculations without using securities, so we'll drop CISECGLQ
m_data.drop(columns="CISECGLQ", inplace=True)

#paper says data before 1976 Q4 is very sporiadic so we'll drop those rows
m_data_b = m_data[m_data["fyearq"] >= 1977]
m_data_b.head()
# Out:
#    gvkey  fyearq    datadate   ACTQ    ATQ  COGSQ  DLTTQ    DPQ    IBQ   LCTQ  \
# 0   1018    1982   9/30/1981    NaN    NaN  0.724    NaN  0.052  0.027    NaN
# 1   1018    1982  12/31/1981    NaN    NaN  0.772    NaN  0.054  0.097    NaN
# 2   1018    1982   3/31/1982    NaN    NaN  0.740    NaN  0.057 -0.398    NaN
# 3   1018    1982   6/30/1982  1.230  3.747  0.686  6.572  0.064  0.296  0.484
# 4   1018    1983   9/30/1982  1.445  3.913  0.688  6.570  0.051  0.010  0.643
#
#    OANCFY  PPENTQ  RECTQ  SALEQ  XSGAQ conm  sic  tic
# 0     NaN     NaN    NaN  1.456  0.480  NaN  NaN  NaN
# 1     NaN     NaN    NaN  1.574  0.488  NaN  NaN  NaN
# 2     NaN     NaN    NaN  1.130  0.570  NaN  NaN  NaN
# 3     NaN   2.362  0.712  1.662  0.427  NaN  NaN  NaN
# 4     NaN   2.313  0.691  1.299  0.391  NaN  NaN  NaN

# %%
#There are a lot of null values
m_data_b.info()
m_data_b.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 76023 entries, 0 to 78624
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   gvkey     76023 non-null  int64
#  1   fyearq    76023 non-null  int64
#  2   datadate  76023 non-null  object
#  3   ACTQ      62293 non-null  float64
#  4   ATQ       65536 non-null  float64
#  5   COGSQ     69435 non-null  float64
#  6   DLTTQ     64990 non-null  float64
#  7   DPQ       62026 non-null  float64
#  8   IBQ       70213 non-null  float64
#  9   LCTQ      62493 non-null  float64
#  10  OANCFY    47994 non-null  float64
#  11  PPENTQ    65168 non-null  float64
#  12  RECTQ     63216 non-null  float64
#  13  SALEQ     70233 non-null  float64
#  14  XSGAQ     57519 non-null  float64
#  15  conm      48241 non-null  object
#  16  sic       48210 non-null  float64
#  17  tic       47012 non-null  object
# dtypes: float64(13), int64(2), object(3)
# memory usage: 11.0+ MB
# Index(['gvkey', 'fyearq', 'datadate', 'ACTQ', 'ATQ', 'COGSQ', 'DLTTQ', 'DPQ',
#        'IBQ', 'LCTQ', 'OANCFY', 'PPENTQ', 'RECTQ', 'SALEQ', 'XSGAQ', 'conm',
#        'sic', 'tic'],
#       dtype='object')

# %%
#There are quite a few rows and companies that have no data at all so we need to get rid of thise
#not including identifier columns bc those seem to be empty for no reason sometimes

value_cols = ['ACTQ', 'ATQ', 'COGSQ', 'DLTTQ', 'DPQ',
       'IBQ', 'LCTQ', 'OANCFY', 'PPENTQ', 'RECTQ', 'SALEQ', 'XSGAQ']

all_na_check = m_data_b[value_cols].isnull().apply(lambda x: all(x), axis=1)
all_na_check.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
#gets rid of rows that have all null values
m_data_c = m_data_b[~all_na_check]
m_data_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 70591 entries, 0 to 78624
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   gvkey     70591 non-null  int64
#  1   fyearq    70591 non-null  int64
#  2   datadate  70591 non-null  object
#  3   ACTQ      62293 non-null  float64
#  4   ATQ       65536 non-null  float64
#  5   COGSQ     69435 non-null  float64
#  6   DLTTQ     64990 non-null  float64
#  7   DPQ       62026 non-null  float64
#  8   IBQ       70213 non-null  float64
#  9   LCTQ      62493 non-null  float64
#  10  OANCFY    47994 non-null  float64
#  11  PPENTQ    65168 non-null  float64
#  12  RECTQ     63216 non-null  float64
#  13  SALEQ     70233 non-null  float64
#  14  XSGAQ     57519 non-null  float64
#  15  conm      47150 non-null  object
#  16  sic       47122 non-null  float64
#  17  tic       46014 non-null  object
# dtypes: float64(13), int64(2), object(3)
# memory usage: 10.2+ MB

# %%
#There's still a good amount of nulls...especially in the cash flow column
#Going to start out by droping any rows that have any null values, will start out using this data set as it is still pretty full
any_na_check = m_data_b[value_cols].isnull().apply(lambda x: any(x), axis=1)
#m_data_full = m_data[value_cols].dropna(axis=0)
m_data_full = m_data_c[~any_na_check]
m_data_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 37745 entries, 206 to 78624
# Data columns (total 18 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   gvkey     37745 non-null  int64
#  1   fyearq    37745 non-null  int64
#  2   datadate  37745 non-null  object
#  3   ACTQ      37745 non-null  float64
#  4   ATQ       37745 non-null  float64
#  5   COGSQ     37745 non-null  float64
#  6   DLTTQ     37745 non-null  float64
#  7   DPQ       37745 non-null  float64
#  8   IBQ       37745 non-null  float64
#  9   LCTQ      37745 non-null  float64
#  10  OANCFY    37745 non-null  float64
#  11  PPENTQ    37745 non-null  float64
#  12  RECTQ     37745 non-null  float64
#  13  SALEQ     37745 non-null  float64
#  14  XSGAQ     37745 non-null  float64
#  15  conm      34260 non-null  object
#  16  sic       34236 non-null  float64
#  17  tic       33423 non-null  object
# dtypes: float64(13), int64(2), object(3)
# memory usage: 5.5+ MB
# C:\Users\Kerstin\AppData\Local\Temp\ipykernel_10416\978180354.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   m_data_full = m_data_c[~any_na_check]

# %%
print("There are ", m_data_full["fyearq"].nunique(), "distinct years with the range", m_data_full["fyearq"].min(), "to", m_data_full["fyearq"].max(),"\n")
print("There are ", m_data_full["gvkey"].nunique(), "distinct companies.\n")
# Out:
# There are  27 distinct years with the range 1987 to 2013
#
# There are  1369 distinct companies.

# %%
#m_data_full.columns
column_names = ["key", "year", "q_end", "current_assets", "total_assets", "cost_of_goods_sold", "total_long_term_debt", "depreciation", "income", "current_liabilities", "cash_flow", "property_plant_equipment", "net_receivables", "net_sales", "sales_general_admin_expense", "company", "sic", "ticker"]
pd.DataFrame(list(zip(m_data_full.columns, column_names)), columns=["Columns", "Names"])
# Out:
#      Columns                        Names
# 0      gvkey                          key
# 1     fyearq                         year
# 2   datadate                        q_end
# 3       ACTQ               current_assets
# 4        ATQ                 total_assets
# 5      COGSQ           cost_of_goods_sold
# 6      DLTTQ         total_long_term_debt
# 7        DPQ                 depreciation
# 8        IBQ                       income
# 9       LCTQ          current_liabilities
# 10    OANCFY                    cash_flow
# 11    PPENTQ     property_plant_equipment
# 12     RECTQ              net_receivables
# 13     SALEQ                    net_sales
# 14     XSGAQ  sales_general_admin_expense
# 15      conm                      company
# 16       sic                          sic
# 17       tic                       ticker

# %%
#I'm only now figuring out that some companies make their fiscal years different than the starndard Jan-Dec quarters...
#should put everyone on the same Jan-Dec Fiscal year
m_data_full.head(10)
# Out:
#      gvkey  fyearq    datadate     ACTQ      ATQ   COGSQ  DLTTQ    DPQ    IBQ  \
# 206   1115    1996  12/31/1995  117.105  167.961  33.890  0.000  0.198  3.541
# 207   1115    1996   3/31/1996  117.985  168.735  36.124  0.000  0.198  3.938
# 208   1115    1996   6/30/1996  121.417  173.127  38.300  0.000  0.198  4.353
# 209   1115    1996   9/30/1996  134.832  186.628  39.517  0.401  2.235  4.805
# 213   1115    1997   9/30/1997  149.003  205.477  42.553  0.308  2.491  6.027
# 217   1115    1998   9/30/1998  189.128  265.057  49.447  0.079  3.644  3.700
# 221   1115    1999   9/30/1999  139.172  239.662  56.063  1.150  7.078 -3.471
# 247   1151    1987   4/30/1988   10.062   16.767   2.721  0.524  0.245 -0.238
# 248   1151    1988   7/31/1988   10.240   16.895   2.153  0.648  0.236  0.133
# 249   1151    1988  10/31/1988    9.249   15.820   2.269  0.647  0.233  0.102
#
#         LCTQ  OANCFY  PPENTQ    RECTQ   SALEQ   XSGAQ                   conm  \
# 206   78.620  -1.345   7.972   64.265  54.988  14.645      ADAC LABORATORIES
# 207   75.525  -1.370   8.022   69.997  58.438  15.148      ADAC LABORATORIES
# 208   77.236   0.640   8.107   71.379  62.434  16.291      ADAC LABORATORIES
# 209   80.512  -7.631   8.393   80.654  64.925  16.957      ADAC LABORATORIES
# 213   64.327  13.585  11.555   99.495  72.480  19.237      ADAC LABORATORIES
# 217   88.678   4.731  11.769  127.590  86.941  23.030      ADAC LABORATORIES
# 221  128.441   6.210  15.555   80.393  84.839  30.143      ADAC LABORATORIES
# 247    8.215   0.445   2.216    3.215   6.505   3.144  AEQUITRON MEDICAL INC
# 248    8.092  -0.284   2.274    4.239   5.891   3.083  AEQUITRON MEDICAL INC
# 249    6.887   0.965   2.297    3.711   5.863   2.960  AEQUITRON MEDICAL INC
#
#         sic   tic
# 206  3844.0  ADAC
# 207  3844.0  ADAC
# 208  3844.0  ADAC
# 209  3844.0  ADAC
# 213  3844.0  ADAC
# 217  3844.0  ADAC
# 221  3844.0  ADAC
# 247  3693.0  AQTN
# 248  3693.0  AQTN
# 249  3693.0  AQTN

# %%
#Creating a new array that is the year that the data reading is in, as opposed to the fiscal year, which differs for some companies
q_year = pd.to_datetime(m_data_full["datadate"]).dt.strftime('%Y')
q_year
# Out:
# 206      1995
# 207      1996
# 208      1996
# 209      1996
# 213      1997
#          ...
# 78618    2011
# 78621    2012
# 78622    2012
# 78623    2013
# 78624    2013
# Name: datadate, Length: 37745, dtype: object

# %%
#New column to reflect the true quarter year
m_data_full["year"] = q_year
m_data_full.head()
# Out:
# C:\Users\Kerstin\AppData\Local\Temp\ipykernel_10416\652438520.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_data_full["year"] = q_year
#      gvkey  fyearq    datadate     ACTQ      ATQ   COGSQ  DLTTQ    DPQ    IBQ  \
# 206   1115    1996  12/31/1995  117.105  167.961  33.890  0.000  0.198  3.541
# 207   1115    1996   3/31/1996  117.985  168.735  36.124  0.000  0.198  3.938
# 208   1115    1996   6/30/1996  121.417  173.127  38.300  0.000  0.198  4.353
# 209   1115    1996   9/30/1996  134.832  186.628  39.517  0.401  2.235  4.805
# 213   1115    1997   9/30/1997  149.003  205.477  42.553  0.308  2.491  6.027
#
#        LCTQ  OANCFY  PPENTQ   RECTQ   SALEQ   XSGAQ               conm  \
# 206  78.620  -1.345   7.972  64.265  54.988  14.645  ADAC LABORATORIES
# 207  75.525  -1.370   8.022  69.997  58.438  15.148  ADAC LABORATORIES
# 208  77.236   0.640   8.107  71.379  62.434  16.291  ADAC LABORATORIES
# 209  80.512  -7.631   8.393  80.654  64.925  16.957  ADAC LABORATORIES
# 213  64.327  13.585  11.555  99.495  72.480  19.237  ADAC LABORATORIES
#
#         sic   tic  year
# 206  3844.0  ADAC  1995
# 207  3844.0  ADAC  1996
# 208  3844.0  ADAC  1996
# 209  3844.0  ADAC  1996
# 213  3844.0  ADAC  1997

# %%
#need to have quarter numbers
quarters = pd.to_datetime(m_data_full["datadate"]).dt.quarter
m_data_full["quarters"] = quarters
m_data_full["YQ"] = pd.PeriodIndex(m_data_full["datadate"], freq="Q")
m_data_full.head()
# Out:
# C:\Users\Kerstin\AppData\Local\Temp\ipykernel_10416\3130081989.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_data_full["quarters"] = quarters
# C:\Users\Kerstin\AppData\Local\Temp\ipykernel_10416\3130081989.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   m_data_full["YQ"] = pd.PeriodIndex(m_data_full["datadate"], freq="Q")
#      gvkey  fyearq    datadate     ACTQ      ATQ   COGSQ  DLTTQ    DPQ    IBQ  \
# 206   1115    1996  12/31/1995  117.105  167.961  33.890  0.000  0.198  3.541
# 207   1115    1996   3/31/1996  117.985  168.735  36.124  0.000  0.198  3.938
# 208   1115    1996   6/30/1996  121.417  173.127  38.300  0.000  0.198  4.353
# 209   1115    1996   9/30/1996  134.832  186.628  39.517  0.401  2.235  4.805
# 213   1115    1997   9/30/1997  149.003  205.477  42.553  0.308  2.491  6.027
#
#        LCTQ  ...  PPENTQ   RECTQ   SALEQ   XSGAQ               conm     sic  \
# 206  78.620  ...   7.972  64.265  54.988  14.645  ADAC LABORATORIES  3844.0
# 207  75.525  ...   8.022  69.997  58.438  15.148  ADAC LABORATORIES  3844.0
# 208  77.236  ...   8.107  71.379  62.434  16.291  ADAC LABORATORIES  3844.0
# 209  80.512  ...   8.393  80.654  64.925  16.957  ADAC LABORATORIES  3844.0
# 213  64.327  ...  11.555  99.495  72.480  19.237  ADAC LABORATORIES  3844.0
#
#       tic  year quarters      YQ
# 206  ADAC  1995        4  1995Q4
# 207  ADAC  1996        1  1996Q1
# 208  ADAC  1996        2  1996Q2
# 209  ADAC  1996        3  1996Q3
# 213  ADAC  1997        3  1997Q3
#
# [5 rows x 21 columns]

# %%
#Some rows have zero values, which can be inaccurate, so to start I'll eliminate those rows
#need to drop rows if there are zeros
m_data_full_0 = m_data_full[~(m_data_full == 0).any(axis=1)]
#m_data_full_0 = m_data_full[(m_data_full == 0.0).any(axis=1)]
m_data_full_0.reset_index(inplace=True, drop=True)
m_data_full_0.head()
# Out:
#    gvkey  fyearq   datadate     ACTQ      ATQ   COGSQ  DLTTQ    DPQ    IBQ  \
# 0   1115    1996  9/30/1996  134.832  186.628  39.517  0.401  2.235  4.805
# 1   1115    1997  9/30/1997  149.003  205.477  42.553  0.308  2.491  6.027
# 2   1115    1998  9/30/1998  189.128  265.057  49.447  0.079  3.644  3.700
# 3   1115    1999  9/30/1999  139.172  239.662  56.063  1.150  7.078 -3.471
# 4   1151    1987  4/30/1988   10.062   16.767   2.721  0.524  0.245 -0.238
#
#       LCTQ  ...  PPENTQ    RECTQ   SALEQ   XSGAQ                   conm  \
# 0   80.512  ...   8.393   80.654  64.925  16.957      ADAC LABORATORIES
# 1   64.327  ...  11.555   99.495  72.480  19.237      ADAC LABORATORIES
# 2   88.678  ...  11.769  127.590  86.941  23.030      ADAC LABORATORIES
# 3  128.441  ...  15.555   80.393  84.839  30.143      ADAC LABORATORIES
# 4    8.215  ...   2.216    3.215   6.505   3.144  AEQUITRON MEDICAL INC
#
#       sic   tic  year quarters      YQ
# 0  3844.0  ADAC  1996        3  1996Q3
# 1  3844.0  ADAC  1997        3  1997Q3
# 2  3844.0  ADAC  1998        3  1998Q3
# 3  3844.0  ADAC  1999        3  1999Q3
# 4  3693.0  AQTN  1988        2  1988Q2
#
# [5 rows x 21 columns]

# %%
print(m_data_full.shape)
print(m_data_full_0.shape)
# Out:
# (37745, 21)
# (26128, 21)

# %%
#In order to get some of the m-values, it requires a higher precision leve. Otherwise we get a NaN which is bad
#attempting to fix this with this precision package
#!pip install mpmath
from mpmath import *

# %%
#testing out the package
print(50-(100/3))
mp.fdiv(100,2) - mp.fdiv(mp.fdiv(100,3), 1)
# Out:
# 16.666666666666664
# mpf('16.666666666666664')

# %%
#using this blocl to check the precision
print(mp)
# Out:
# Mpmath settings:
#   mp.prec = 332196            [default: 53]
#   mp.dps = 100000             [default: 15]
#   mp.trap_complex = False     [default: False]

# %%
#This cell code has the calculations and definitions for M-Score and its components using the high precion

#create functions for each variable needed to calculate M-Score
#dft will be the row of the current t
#dft_1 will be the row of t-1

#10000 was the last one I was able to get to run, but there were still NaNs
#100000 I let run for 30 minutes, and it didn't even get close
mp.dps = 50000
mp.pretty= False

#Days Sales in Receivables
def DSRI(dft, dft_1):
    #x = dft["RECTQ"]/dft["SALEQ"]
    #y = dft_1["RECTQ"]/dft_1["SALEQ"]
    #return x/y
    x = mp.fdiv(dft["RECTQ"],dft["SALEQ"])
    y = mp.fdiv(dft_1["RECTQ"],dft_1["SALEQ"])
    return mp.fdiv(x,y)

#Gross Margin index
def GMI(dft,dft_1):
    #x = (dft_1["SALEQ"]-dft_1["COGSQ"])/dft_1["SALEQ"]
    #y = (dft["SALEQ"]-dft["COGSQ"])/dft["SALEQ"]
    #return x/y
    x = mp.fdiv(dft_1["SALEQ"]-dft_1["COGSQ"],dft_1["SALEQ"])
    y = mp.fdiv(dft["SALEQ"]-dft["COGSQ"],dft["SALEQ"])
    return mp.fdiv(x,y)

#Asset Quality Index
def AQI(dft,dft_1):
    #x = 1 - (dft["ACTQ"] + dft["PPENTQ"])/dft["ATQ"]
    #y = 1 - (dft_1["ACTQ"] + dft_1["PPENTQ"])/dft_1["ATQ"]
    #return x/y
    x = mp.fsub(1,  mp.fdiv(mp.fadd(dft["ACTQ"], dft["PPENTQ"]),dft["ATQ"]))
    y = mp.fsub(1,  mp.fdiv(mp.fadd(dft_1["ACTQ"], dft_1["PPENTQ"]),dft_1["ATQ"]))
    return mp.fdiv(x,y)

#Sales Growth Index
def SGI(dft,dft_1):
    #return dft["SALEQ"]/dft_1["SALEQ"]
    return mp.fdiv(dft["SALEQ"],dft_1["SALEQ"])

#Depreciation Index
def DEPI(dft,dft_1):
    #x = dft_1["DPQ"]/(dft_1["PPENTQ"] + dft_1["DPQ"])
    #y = dft["DPQ"]/(dft["PPENTQ"] + dft["DPQ"])
    #return x/y
    x = mp.fdiv(dft_1["DPQ"],(dft_1["PPENTQ"] + dft_1["DPQ"]))
    y = mp.fdiv(dft["DPQ"],(dft["PPENTQ"] + dft["DPQ"]))
    return mp.fdiv(x,y)



#Sales, General, and Admin expenses
def SGAI(dft,dft_1):
    #return (dft["XSGAQ"]/dft["SALEQ"])/(dft_1["XSGAQ"]/dft_1["SALEQ"])
    return mp.fdiv(mp.fdiv(dft["XSGAQ"],dft["SALEQ"]),mp.fdiv(dft_1["XSGAQ"],dft_1["SALEQ"]))

#Leverage Index
def LVGI(dft, dft_1):
    #x = (dft["LCTQ"] + dft["DLTTQ"])/dft["ATQ"]
    #y = (dft_1["LCTQ"] + dft_1["DLTTQ"])/dft_1["ATQ"]
    #return x/y
    x = mp.fdiv(dft["LCTQ"] + dft["DLTTQ"],dft["ATQ"])
    y = mp.fdiv(dft_1["LCTQ"] + dft_1["DLTTQ"],dft_1["ATQ"])
    return mp.fdiv(x,y)

#Total Accrual to Total Assets
def TATA(dft):
    #return (dft["IBQ"] - dft["OANCFY"])/dft["ATQ"]
    return mp.fdiv(dft["IBQ"] - dft["OANCFY"],dft["ATQ"])

#M-Score for time t
def M(dft, dft_1):
    return -4.84 + 0.92*DSRI(dft, dft_1) \
                 + 0.528*GMI(dft, dft_1) \
                 + 0.404*AQI(dft, dft_1) \
                 + 0.892*SGI(dft, dft_1) \
                 + 0.115*DEPI(dft, dft_1) \
                 - 0.172*SGAI(dft, dft_1) \
                 - 0.327*LVGI(dft, dft_1) \
                 + 4.679*TATA(dft)

# %%
import math

# %%
#These are the calculations for m-score and its components using regular algebra. It results in a bunch of nulls

#create functions for each variable needed to calculate M-Score
#dft will be the row of the current t
#dft_1 will be the row of t-1

#Days Sales in Receivables
def DSRI(dft, dft_1):
    x = dft["RECTQ"]/dft["SALEQ"]
    y = dft_1["RECTQ"]/dft_1["SALEQ"]
    #return exp(math.log(x) - math.log(y))
    return x/y
    

#Gross Margin index
def GMI(dft,dft_1):
    x = (dft_1["SALEQ"]-dft_1["COGSQ"])/dft_1["SALEQ"]
    y = (dft["SALEQ"]-dft["COGSQ"])/dft["SALEQ"]
    #return exp(math.log(x) - math.log(y))
    return x/y


#Asset Quality Index
def AQI(dft,dft_1):
    x = 1 - (dft["ACTQ"] + dft["PPENTQ"])/dft["ATQ"]
    y = 1 - (dft_1["ACTQ"] + dft_1["PPENTQ"])/dft_1["ATQ"]
    #return exp(math.log(x) - math.log(y))
    return x/y
    

#Sales Growth Index
def SGI(dft,dft_1):
    x = dft["SALEQ"]
    y = dft_1["SALEQ"]
    #return exp(math.log(x) - math.log(y))
    return x/y
    

#Depreciation Index
def DEPI(dft,dft_1):
    x = dft_1["DPQ"]/(dft_1["PPENTQ"] + dft_1["DPQ"])
    y = dft["DPQ"]/(dft["PPENTQ"] + dft["DPQ"])
    #return  exp(math.log(x) - math.log(y))
    return x/y
  



#Sales, General, and Admin expenses
def SGAI(dft,dft_1):
    x = (dft["XSGAQ"]/dft["SALEQ"])
    y = (dft_1["XSGAQ"]/dft_1["SALEQ"])
    #return  exp(math.log(x) - math.log(y))
    return x/y

#Leverage Index
def LVGI(dft, dft_1):
    x = (dft["LCTQ"] + dft["DLTTQ"])/dft["ATQ"]
    y = (dft_1["LCTQ"] + dft_1["DLTTQ"])/dft_1["ATQ"]
    #return exp(math.log(x) - math.log(y))
    return x/y


#Total Accrual to Total Assets
def TATA(dft):
    x = (dft["IBQ"] - dft["OANCFY"])
    y = dft["ATQ"]
    #print(math.log(x))
    #print(math.log(y))
    #return exp(x/y)
    return x/y

#M-Score for time t
def M(dft, dft_1):
    return -4.84 + 0.92*DSRI(dft, dft_1) \
                 + 0.528*GMI(dft, dft_1) \
                 + 0.404*AQI(dft, dft_1) \
                 + 0.892*SGI(dft, dft_1) \
                 + 0.115*DEPI(dft, dft_1) \
                 - 0.172*SGAI(dft, dft_1) \
                 - 0.327*LVGI(dft, dft_1) \
                 + 4.679*math.log(TATA(dft))

# %%
#This was me trying to figure out f I was getting the correct values, it seems like I was
-4.84 + (.92*1.174) + (.528*1.039) + (0.404*-1.026) + (0.892*1.002) + (.115*0.988) - (0.172*0.9898) - (0.327*0.9705) + (4.679*0.069)
# Out:
# -2.7831760999999995

# %%
#the M-score needs to be calculated for each company, so we'll make a dataframe based on the key
comp_keys = m_data_full_0["gvkey"].unique()

def comp_df(df, key):

    return df[df["gvkey"] == key]

# %%
#need the M-scores for each calendar quarter


list_of_rows =[]
for i in comp_keys:
    k_df = comp_df(m_data_full_0, i)
    k_df = k_df.reset_index(drop=True)

    for index, row in k_df.iterrows():
        if index == 0: continue
        

        score = M(k_df.iloc[index], k_df.iloc[index-1])

        new_row = [row["gvkey"], row["conm"], row["tic"], row["year"], row["YQ"], score]
        list_of_rows.append(new_row)


m_score_df = pd.DataFrame(list_of_rows, columns=["Key", "Company", "Ticker", "Year", "Quarter", "M-Score"])
m_score_df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Kerstin\Desktop\GT\6203\Project\m_score.ipynb Cell 26 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/Kerstin/Desktop/GT/6203/Project/m_score.ipynb#X50sZmlsZQ%3D%3D?line=8'>9</a> for index, row in k_df.iterrows():
#      <a href='vscode-notebook-cell:/c%3A/Users/Kerstin/Desktop/GT/6203/Project/m_score.ipynb#X50sZmlsZQ%3D%3D?line=9'>10</a>     if index == 0: continue
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Kerstin/Desktop/GT/6203/Project/m_score.ipynb#X50sZmlsZQ%3D%3D?line=12'>13</a>     score = M(k_df.iloc[index], k_df.iloc[index-1])
#      <a href='vscode-notebook-cell:/c%3A/Users/Kerstin/Desktop/GT/6203/Project/m_score.ipynb#X50sZmlsZQ%3D%3D?line=14'>15</a>     new_row = [row["gvkey"], row["conm"], row["tic"], row["year"], row["YQ"], score]
#      <a href='vscode-notebook-cell:/c%3A/Users/Kerstin/Desktop/GT/6203/Project/m_score.ipynb#X50sZmlsZQ%3D%3D?line=15'>16</a>     list_of_rows.append(new_row)
#
# c:\Users\Kerstin\Desktop\GT\6203\Project\m_score.ipynb Cell 26 line 7
#      <a href='vscode-notebook-cell:/c%3A/Users/Kerstin/Desktop/GT/6203/Project/m_score.ipynb#X50sZmlsZQ%3D%3D?line=73'>74</a> def M(dft, dft_1):
#      <a href='vscode-notebook-cell:/c%3A/Users/Kerstin/Desktop/GT/6203/Project/m_score.ipynb#X50sZmlsZQ%3D%3D?line=74'>75</a>     return -4.84 + 0.92*DSRI(dft, dft_1) \
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Kerstin/Desktop/GT/6203/Project/m_score.ipynb#X50sZmlsZQ%3D%3D?line=75'>76</a>                  + 0.528*GMI(dft, dft_1) \
#      <a href='vscode-notebook-cell:/c%3A/Users/Kerstin/Desktop/GT/6203/Project/m_score.ipynb#X50sZmlsZQ%3D%3D?line=76'>77</a>                  + 0.404*AQI(dft, dft_1) \
#      <a href='vscode-notebook-cell:/c%3A/Users/Kerstin/Desktop/GT/6203/Project/m_score.ipynb#X50sZmlsZQ%3D%3D?line=77'>78</a>                  + 0.892*SGI(dft, dft_1) \
#      <a href='vscode-notebook-cell:/c%3A/Users/Kerstin/Desktop/GT/6203/Project/m_score.ipynb#X50sZmlsZQ%3D%3D?line=78'>79</a>                  + 0.115*DEPI(dft, dft_1) \
#      <a href='vscode-notebook-cell:/c%3A/Users/Kerstin/Desktop/GT/6203/Project/m_score.ipynb#X50sZmlsZQ%3D%3D?line=79'>80</a>                  - 0.172*SGAI(dft, dft_1) \
#      <a href='vscode-notebook-cell:/c%3A/Users/Kerstin/Desktop/GT/6203/Project/m_score.ipynb#X50sZmlsZQ%3D%3D?line=80'>81</a>                  - 0.327*LVGI(dft, dft_1) \
#      <a href='vscode-notebook-cell:/c%3A/Users/Kerstin/Desktop/GT/6203/Project/m_score.ipynb#X50sZmlsZQ%3D%3D?line=81'>82</a>                  + 4.679*math.log(TATA(dft))
#
# c:\Users\Kerstin\Desktop\GT\6203\Project\m_score.ipynb Cell 26 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/Kerstin/Desktop/GT/6203/Project/m_score.ipynb#X50sZmlsZQ%3D%3D?line=16'>17</a> x = (dft_1["SALEQ"]-dft_1["COGSQ"])/dft_1["SALEQ"]
#      <a href='vscode-notebook-cell:/c%3A/Users/Kerstin/Desktop/GT/6203/Project/m_score.ipynb#X50sZmlsZQ%3D%3D?line=17'>18</a> y = (dft["SALEQ"]-dft["COGSQ"])/dft["SALEQ"]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/Kerstin/Desktop/GT/6203/Project/m_score.ipynb#X50sZmlsZQ%3D%3D?line=18'>19</a> return exp(math.log(x) - math.log(y))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mpmath\ctx_mp_python.py:1000, in PythonMPContext._wrap_libmp_function.<locals>.f(x, **kwargs)
#     998 if hasattr(x, '_mpf_'):
#     999     try:
# -> 1000         return ctx.make_mpf(mpf_f(x._mpf_, prec, rounding))
#    1001     except ComplexResult:
#    1002         # Handle propagation to complex
#    1003         if ctx.trap_complex:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mpmath\libmp\libelefun.py:1187, in mpf_exp(x, prec, rnd)
#    1185             t = man >> (-offset)
#    1186         n = 0
# -> 1187     man = exp_basecase(t, wp)
#    1188     return from_man_exp(man, n-wp, prec, rnd)
#    1189 if not exp:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mpmath\libmp\libelefun.py:1093, in exp_basecase(x, prec)
#    1087 """
#    1088 Compute exp(x) as a fixed-point number. Works for any x,
#    1089 but for speed should have |x| < 1. For an arbitrary number,
#    1090 use exp(x) = exp(x-m*log(2)) * 2^m where m = floor(x/log(2)).
#    1091 """
#    1092 if prec > EXP_COSH_CUTOFF:
# -> 1093     return exponential_series(x, prec, 0)
#    1094 r = int(prec**0.5)
#    1095 prec += r
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\mpmath\libmp\libelefun.py:1071, in exponential_series(x, prec, type)
#    1069         v = c + s
#    1070     for i in xrange(r):
# -> 1071         v = (v*v) >> wp
#    1072     return v >> extra
#    1073 else:
#    1074     # Repeatedly apply the double-angle formula
#    1075     # cosh(2*x) = 2*cosh(x)^2 - 1
#    1076     # cos(2*x) = 2*cos(x)^2 - 1
#
# KeyboardInterrupt:

# %%
#whenever the m-score function is stopped by a zero division error, this tells us where it stopped
m_data_full_0.head(2)
list_of_rows[-1]
# Out:
# [1151,
#  'AEQUITRON MEDICAL INC',
#  'AQTN',
#  '1994',
#  Period('1994Q1', 'Q-DEC'),
#  mpf('-2....')]

# %%
(m_data_full_0).shape
# Out:
# (26128, 21)

# %%
#This is to save the original version of the m score df calculated with normal pprecision
OG_M = m_score_df
OG_M.shape

# %%
#This is where I want to store the non-precision math m_score calculations
temp = m_score_df[~m_score_df["M-Score"].isna()]
temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 24679 entries, 0 to 25027
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Key      24679 non-null  int64
#  1   Company  23229 non-null  object
#  2   Ticker   22525 non-null  object
#  3   Year     24679 non-null  object
#  4   Quarter  24679 non-null  period[Q-DEC]
#  5   M-Score  24679 non-null  float64
# dtypes: float64(1), int64(1), object(3), period[Q-DEC](1)
# memory usage: 1.0+ MB

# %%
m_data_full_0[m_data_full_0["gvkey"] == 2951].head(10)
# Out:
#       gvkey  fyearq    datadate    ACTQ     ATQ  COGSQ  DLTTQ    DPQ    IBQ  \
# 1635   2951    1988  1988-09-30   9.095  10.573  1.229  3.266  0.154 -0.610
# 1636   2951    1989  1988-12-31   9.731  11.124  1.628  3.237  0.137  0.352
# 1637   2951    1989  1989-03-31   9.855  11.110  1.651  3.192  0.140  0.158
# 1638   2951    1989  1989-06-30   9.186  10.299  1.793  1.530  0.141  0.236
# 1639   2951    1989  1989-09-30   8.194   9.211  1.418  1.353  0.138  0.468
# 1640   2951    1990  1989-12-31   8.729   9.705  1.578  1.202  0.099  0.423
# 1641   2951    1990  1990-03-31   9.725  10.720  2.080  1.206  0.105  0.628
# 1642   2951    1990  1990-06-30  10.874  11.829  2.097  1.175  0.115  0.868
# 1643   2951    1990  1990-09-30  12.248  13.177  1.997  0.144  0.098  0.509
# 1644   2951    1991  1990-12-31  12.619  13.522  2.127  0.138  0.099  0.467
#
#        LCTQ  ...  PPENTQ  RECTQ  SALEQ  XSGAQ                   conm     sic  \
# 1635  5.445  ...   1.387  3.286  3.135  2.139  CHECK TECHNOLOGY CORP  3555.0
# 1636  5.608  ...   1.315  3.763  4.514  2.057  CHECK TECHNOLOGY CORP  3555.0
# 1637  5.536  ...   1.191  4.124  4.280  1.951  CHECK TECHNOLOGY CORP  3555.0
# 1638  6.325  ...   1.062  3.397  4.719  1.992  CHECK TECHNOLOGY CORP  3555.0
# 1639  4.965  ...   0.979  2.528  4.034  2.140  CHECK TECHNOLOGY CORP  3555.0
# 1640  5.224  ...   0.953  3.414  4.138  2.067  CHECK TECHNOLOGY CORP  3555.0
# 1641  5.598  ...   0.986  4.483  5.132  2.160  CHECK TECHNOLOGY CORP  3555.0
# 1642  2.898  ...   0.955  5.236  5.383  2.300  CHECK TECHNOLOGY CORP  3555.0
# 1643  4.521  ...   0.929  4.003  5.351  2.708  CHECK TECHNOLOGY CORP  3555.0
# 1644  4.390  ...   0.903  4.712  5.364  2.687  CHECK TECHNOLOGY CORP  3555.0
#
#        tic  year quarters      YQ
# 1635  CTCQ  1988        3  1988Q3
# 1636  CTCQ  1988        4  1988Q4
# 1637  CTCQ  1989        1  1989Q1
# 1638  CTCQ  1989        2  1989Q2
# 1639  CTCQ  1989        3  1989Q3
# 1640  CTCQ  1989        4  1989Q4
# 1641  CTCQ  1990        1  1990Q1
# 1642  CTCQ  1990        2  1990Q2
# 1643  CTCQ  1990        3  1990Q3
# 1644  CTCQ  1990        4  1990Q4
#
# [10 rows x 21 columns]

# %%
#This was a test to figure out what was wrong with the function
#The problem is that specifically the AQI calculations results in numbers so small that they read as zeros, which leads to zeros in the denominator
M(m_data_full_0.iloc[1643], m_data_full_0.iloc[1642])
# Out:
# C:\Users\Kerstin\AppData\Local\Temp/ipykernel_17496/3612848250.py:19: RuntimeWarning: invalid value encountered in double_scalars
#   return x/y
# nan

# %%
#Was searching for the prblem row
list_of_rows[1601]
# Out:
# [2951, 'CHECK TECHNOLOGY CORP', 'CTCQ', '1990', Period('1990Q3', 'Q-DEC'), nan]

# %%
#grouping by quarter to average m_scores and so I could then plot them
#need to do a weighted average somehow but will start here
m_score_means = temp.groupby(["Quarter"]).mean()["M-Score"]

# %%
len(temp.groupby(["Quarter"]).count()["M-Score"])
# Out:
# 105

# %%
#need to plot
print(m_score_means[1:20])
# Out:
# Quarter
# 1987Q3   -2.619169e+00
# 1987Q4   -2.716349e+00
# 1988Q1    3.588350e+01
# 1988Q2             NaN
# 1988Q3   -2.413361e+00
# 1988Q4             NaN
# 1989Q1   -4.551398e+10
# 1989Q2   -2.496384e+00
# 1989Q3             NaN
# 1989Q4             NaN
# 1990Q1             NaN
# 1990Q2   -2.464984e+00
# 1990Q3   -2.546829e+00
# 1990Q4             NaN
# 1991Q1             NaN
# 1991Q2             NaN
# 1991Q3             NaN
# 1991Q4             NaN
# 1992Q1             NaN
# Freq: Q-DEC, Name: M-Score, dtype: float64
