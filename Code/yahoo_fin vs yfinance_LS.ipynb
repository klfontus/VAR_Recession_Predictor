# %%
# Install yahoo_fin
pip install yahoo_fin

# %%
pip install requests_html

# %%
from yahoo_fin.stock_info import *

# %%
# get all historical price data
nasdaq_price = get_data('^IXIC', start_date = None, end_date = None, index_as_date = True, interval = '1mo')

print(type(nasdaq_price)) # Is it a dataframe?
print(nasdaq_price.shape) # what is the shape?
display(nasdaq_price.tail(20)) #

# %%
# get all historical price data
dow_price = get_data('^DJI', start_date = None, end_date = None, index_as_date = True, interval = '1mo')

print(type(dow_price)) # Is it a dataframe?
print(dow_price.shape) # what is the shape?
display(dow_price.head(20)) #

# %%
# get all historical price data
sp500_price = get_data('^GSPC', start_date = None, end_date = None, index_as_date = True, interval = '1mo')

print(type(sp500_price)) # Is it a dataframe?
print(sp500_price.shape) # what is the shape?
display(sp500_price.head(20)) #

# %%
#Install yfinance
pip install yfinance

import yfinance as yf

# %%
nasdaq= yf.Ticker('^IXIC')

n_his = nasdaq.history(period="max", interval="3mo", start='1985-01-01')

# history(self, period="1mo", interval="1d",
#             start=None, end=None, prepost=False, actions=True,
#             auto_adjust=True, back_adjust=False,
#             proxy=None, rounding=False, tz=None, timeout=None, **kwargs):

display(n_his.head(20))
display(n_his.tail(20))
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1985-01-01 00:00:00-05:00  247.100006  289.299988  245.800003  279.200012
# 1985-04-01 00:00:00-05:00  279.500000  296.200012  276.200012  296.200012
# 1985-07-01 00:00:00-04:00  295.899994  307.899994  279.500000  280.299988
# 1985-10-01 00:00:00-04:00  280.600006  325.600006  276.600006  324.899994
# 1986-01-01 00:00:00-05:00  325.000000  374.700012  322.100006  374.700012
# 1986-04-01 00:00:00-05:00  375.799988  405.500000  368.000000  405.500000
# 1986-07-01 00:00:00-04:00  407.000000  411.299988  342.299988  350.700012
# 1986-10-01 00:00:00-04:00  352.500000  364.700012  347.000000  348.799988
# 1987-01-01 00:00:00-05:00  351.299988  440.000000  348.799988  430.100006
# 1987-04-01 00:00:00-05:00  426.299988  439.200012  404.500000  424.700012
# 1987-07-01 00:00:00-04:00  424.500000  456.299988  423.700012  444.299988
# 1987-10-01 00:00:00-04:00  446.200012  453.700012  288.500000  330.500000
# ...

# %%
dow= yf.Ticker('^DJI')

d_his = nasdaq.history(period="max", interval="3mo")

# history(self, period="1mo", interval="1d",
#             start=None, end=None, prepost=False, actions=True,
#             auto_adjust=True, back_adjust=False,
#             proxy=None, rounding=False, tz=None, timeout=None, **kwargs):

display(d_his.head(20))
display(d_his.tail(20))
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1984-11-01 00:00:00-05:00  247.100006  278.899994  245.800003  278.700012
# 1985-02-01 00:00:00-05:00  277.899994  289.299988  275.600006  280.600006
# 1985-05-01 00:00:00-04:00  280.500000  307.899994  278.799988  301.299988
# 1985-08-01 00:00:00-04:00  302.600006  304.600006  276.600006  292.500000
# 1985-11-01 00:00:00-05:00  293.000000  335.799988  292.500000  335.799988
# 1986-02-01 00:00:00-05:00  336.100006  393.000000  335.799988  383.200012
# 1986-05-01 00:00:00-04:00  383.200012  411.299988  369.100006  371.399994
# 1986-08-01 00:00:00-04:00  372.500000  384.000000  342.299988  360.799988
# 1986-11-01 00:00:00-05:00  361.000000  396.200012  347.000000  392.100006
# 1987-02-01 00:00:00-05:00  393.799988  440.000000  392.000000  417.799988
# 1987-05-01 00:00:00-04:00  418.600006  434.899994  404.500000  434.899994
# 1987-08-01 00:00:00-04:00  433.299988  456.299988  288.500000  323.299988
# ...

# %%
sp500= yf.Ticker('^GSPC')

sp_his = nasdaq.history(period="max", interval="3mo", start='1985-01-01')

# history(self, period="1mo", interval="1d",
#             start=None, end=None, prepost=False, actions=True,
#             auto_adjust=True, back_adjust=False,
#             proxy=None, rounding=False, tz=None, timeout=None, **kwargs):

display(sp_his.head(20))
display(sp_his.tail(20))
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1985-01-01 00:00:00-05:00  247.100006  289.299988  245.800003  279.200012
# 1985-04-01 00:00:00-05:00  279.500000  296.200012  276.200012  296.200012
# 1985-07-01 00:00:00-04:00  295.899994  307.899994  279.500000  280.299988
# 1985-10-01 00:00:00-04:00  280.600006  325.600006  276.600006  324.899994
# 1986-01-01 00:00:00-05:00  325.000000  374.700012  322.100006  374.700012
# 1986-04-01 00:00:00-05:00  375.799988  405.500000  368.000000  405.500000
# 1986-07-01 00:00:00-04:00  407.000000  411.299988  342.299988  350.700012
# 1986-10-01 00:00:00-04:00  352.500000  364.700012  347.000000  348.799988
# 1987-01-01 00:00:00-05:00  351.299988  440.000000  348.799988  430.100006
# 1987-04-01 00:00:00-05:00  426.299988  439.200012  404.500000  424.700012
# 1987-07-01 00:00:00-04:00  424.500000  456.299988  423.700012  444.299988
# 1987-10-01 00:00:00-04:00  446.200012  453.700012  288.500000  330.500000
# ...
